# %% [markdown]
# ## Importing dependencies

# %%
import gym
from gym import Env
from gym.spaces import Box, Dict, Discrete

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

import numpy as np
import random
import os

import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn

# %% [markdown]
# ## Types of Spaces

# %%
discrete_space = Discrete(3)            # Takes one of three different values (0, 1, 2)
discrete_space.sample()
# Out:
# 1

# %%
box_space = Box(0, 1, shape=(2, 2))                 # Floating values between 0 and 1 in the shape of 2 × 2 matrix
box_space.sample()
# Out:
# array([[0.07707087, 0.341452  ],
#        [0.5822266 , 0.03030989]], dtype=float32)

# %%
params = {'height': Discrete(2), 'speed': Box(0, 100, shape=(1,))}
dict_space = Dict(params)
dict_space.sample()
# Out:
# OrderedDict([('height', 1), ('speed', array([0.1801315], dtype=float32))])

# %% [markdown]
# ## Building an Environment
#
# - Build an agent to give us the best shower possible
# - Temperature fluctuates randomly
# - Ideal temperature: 37 to 39 °C

# %%
class ShowerTempEnv(Env):
    def __init__(self):
        self.action_space = Discrete(3)                 # Turn the tap Up, Down or Hold
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        self.state = 38 + random.randint(-3, 3)
        self.shower_length = 60

    def reset(self):
        self.state = np.array([38 + random.randint(-3, 3)]).astype(float)
        self.shower_length = 60
        return self.state

    def step(self, action):
        self.state += action - 1
        self.shower_length -= 1

        if 37 <= self.state <= 39:
            reward = 1
        else:
            reward = -1

        if self.shower_length <= 0:
            done = True
        else:
            done = False
        
        info = {}

        return self.state, reward, done, info

# %% [markdown]
# ## Testing the Environment

# %%
env = ShowerTempEnv()
print(f"Action Space: {env.action_space}")
print(f"Observation Space: {env.observation_space}")
# Out:
# Action Space: Discrete(3)
# Observation Space: Box(0.0, 100.0, (1,), float32)

# %%
episodes = 5

for episode in range(1, episodes+1):
    obs = env.reset()
    score = 0
    done = False

    while not done:
        action = env.action_space.sample()
        obs, reward, done, info = env.step(action)
        score += reward

    print(f"Episode: {episode} | Score: {score}")
# Out:
# Episode: 1 | Score: 22
# Episode: 2 | Score: -60
# Episode: 3 | Score: 42
# Episode: 4 | Score: -50
# Episode: 5 | Score: -60

# %% [markdown]
# ## Train Model

# %%
log_path = os.path.join('training', 'logs')
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=500000)
# Out:
# Logging to training\logs\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 27       |
# | time/              |          |
# |    fps             | 1203     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 24.6        |
# | time/                   |             |
# |    fps                  | 880         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016455702 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | -0.178      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.9        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | 0.00463     |
# |    value_loss           | 70.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 25           |
# | time/                   |              |
# |    fps                  | 634          |
# |    iterations           | 3            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0019949423 |
# |    clip_fraction        | 0.0506       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.494       |
# |    explained_variance   | 0.073        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.6         |
# |    n_updates            | 600          |
# |    policy_gradient_loss | 0.0024       |
# |    value_loss           | 71.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 23           |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 4            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0030542829 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.498       |
# |    explained_variance   | 0.0888       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.4         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 76.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 26.2         |
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 5            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0012107895 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.9         |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.000178    |
# |    value_loss           | 89.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 29.6        |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 6           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012036884 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.0958      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.2        |
# |    n_updates            | 630         |
# |    policy_gradient_loss | 0.00213     |
# |    value_loss           | 77.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 34.4         |
# | time/                   |              |
# |    fps                  | 362          |
# |    iterations           | 7            |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0021833973 |
# |    clip_fraction        | 0.0723       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.442       |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.5         |
# |    n_updates            | 640          |
# |    policy_gradient_loss | 0.00437      |
# |    value_loss           | 77.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 31.2         |
# | time/                   |              |
# |    fps                  | 366          |
# |    iterations           | 8            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0015207226 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.459       |
# |    explained_variance   | 0.011        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.1         |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.000702    |
# |    value_loss           | 93.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 23.1         |
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 9            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0038123261 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.459       |
# |    explained_variance   | 0.137        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.7         |
# |    n_updates            | 660          |
# |    policy_gradient_loss | 0.00063      |
# |    value_loss           | 101          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 25.4         |
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 10           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0045631835 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.431       |
# |    explained_variance   | 0.286        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.6         |
# |    n_updates            | 670          |
# |    policy_gradient_loss | 0.00139      |
# |    value_loss           | 99.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 27.4        |
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 11          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006093548 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.414      |
# |    explained_variance   | 0.273       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.3        |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.00443    |
# |    value_loss           | 89.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 31.3         |
# | time/                   |              |
# |    fps                  | 430          |
# |    iterations           | 12           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0021944332 |
# |    clip_fraction        | 0.0465       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.404       |
# |    explained_variance   | -0.26        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.3         |
# |    n_updates            | 690          |
# |    policy_gradient_loss | 0.00299      |
# |    value_loss           | 76.6         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 26.5       |
# | time/                   |            |
# |    fps                  | 410        |
# |    iterations           | 13         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01195599 |
# |    clip_fraction        | 0.0492     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.388     |
# |    explained_variance   | 0.113      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 41.7       |
# |    n_updates            | 700        |
# |    policy_gradient_loss | 0.00793    |
# |    value_loss           | 86.5       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 21           |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 14           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0038609034 |
# |    clip_fraction        | 0.0756       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.399       |
# |    explained_variance   | -0.0289      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.2         |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.000882    |
# |    value_loss           | 83.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 20.3        |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 15          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020572692 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.372      |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.5        |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 99.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 22.4         |
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 16           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0029928344 |
# |    clip_fraction        | 0.069        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.385       |
# |    explained_variance   | 0.287        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47           |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -0.00343     |
# |    value_loss           | 81.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 26.8        |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 17          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.004461685 |
# |    clip_fraction        | 0.0428      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.384      |
# |    explained_variance   | 0.186       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.1        |
# |    n_updates            | 740         |
# |    policy_gradient_loss | 0.003       |
# |    value_loss           | 92.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 31.4         |
# | time/                   |              |
# |    fps                  | 364          |
# |    iterations           | 18           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0036330274 |
# |    clip_fraction        | 0.0633       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.397       |
# |    explained_variance   | -0.182       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.8         |
# |    n_updates            | 750          |
# |    policy_gradient_loss | 0.00189      |
# |    value_loss           | 85.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 30.2        |
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 19          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009896419 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.349      |
# |    explained_variance   | 0.0753      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.6        |
# |    n_updates            | 760         |
# |    policy_gradient_loss | 0.0203      |
# |    value_loss           | 79          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 32.7         |
# | time/                   |              |
# |    fps                  | 357          |
# |    iterations           | 20           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0013021964 |
# |    clip_fraction        | 0.0666       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | 0.185        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.2         |
# |    n_updates            | 770          |
# |    policy_gradient_loss | 0.0119       |
# |    value_loss           | 86.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 29.7        |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 21          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.018121485 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.356      |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.9        |
# |    n_updates            | 780         |
# |    policy_gradient_loss | 0.0174      |
# |    value_loss           | 91.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 32.1        |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 22          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004959952 |
# |    clip_fraction        | 0.0276      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.303      |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.3        |
# |    n_updates            | 790         |
# |    policy_gradient_loss | 0.00236     |
# |    value_loss           | 89.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 33.2         |
# | time/                   |              |
# |    fps                  | 349          |
# |    iterations           | 23           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0010735614 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.291       |
# |    explained_variance   | 0.22         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44           |
# |    n_updates            | 800          |
# |    policy_gradient_loss | 0.000747     |
# |    value_loss           | 107          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 30.3         |
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 24           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0016903356 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.283       |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.7         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | 0.00179      |
# |    value_loss           | 93.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 28.3         |
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 25           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0028668419 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.32        |
# |    explained_variance   | 0.329        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.6         |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00315     |
# |    value_loss           | 102          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 28.2         |
# | time/                   |              |
# |    fps                  | 344          |
# |    iterations           | 26           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0020514606 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | 0.297        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.5         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | 0.000205     |
# |    value_loss           | 107          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 31.1          |
# | time/                   |               |
# |    fps                  | 342           |
# |    iterations           | 27            |
# |    time_elapsed         | 161           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00047819127 |
# |    clip_fraction        | 0.0438        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.356        |
# |    explained_variance   | 0.184         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 48.4          |
# |    n_updates            | 840           |
# |    policy_gradient_loss | 0.00612       |
# |    value_loss           | 94.8          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 33          |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 28          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013602439 |
# |    clip_fraction        | 0.0452      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.359      |
# |    explained_variance   | 0.215       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.8        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | 0.00251     |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 31.6         |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 29           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0017782003 |
# |    clip_fraction        | 0.0668       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | 0.197        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.3         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | 0.01         |
# |    value_loss           | 93.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 34.7         |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 30           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0051461235 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.361       |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.9         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | 0.0024       |
# |    value_loss           | 99.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 37          |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 31          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.022109773 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.4        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | 0.00747     |
# |    value_loss           | 106         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 29.7         |
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 32           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0047973897 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.332       |
# |    explained_variance   | 0.0426       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.3         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | 0.00234      |
# |    value_loss           | 105          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 26          |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 33          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.023214798 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.314      |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.5        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | 0.00611     |
# |    value_loss           | 107         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 19.6        |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 34          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004228425 |
# |    clip_fraction        | 0.0735      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | 0.171       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.8        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | 0.0163      |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 23.5        |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 35          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009391319 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.22       |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.4        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.00458     |
# |    value_loss           | 104         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 18.7         |
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 36           |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0026802835 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | 0.295        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.2         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | 0.00322      |
# |    value_loss           | 98.1         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 10.8       |
# | time/                   |            |
# |    fps                  | 345        |
# |    iterations           | 37         |
# |    time_elapsed         | 219        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.09636246 |
# |    clip_fraction        | 0.0952     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.31      |
# |    explained_variance   | 0.467      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 47.9       |
# |    n_updates            | 940        |
# |    policy_gradient_loss | 0.00925    |
# |    value_loss           | 101        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 11          |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 38          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.111937076 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.291      |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.1        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00533    |
# |    value_loss           | 78.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 11          |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 39          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.015208162 |
# |    clip_fraction        | 0.0224      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.218      |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.9        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00188    |
# |    value_loss           | 110         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 3.14       |
# | time/                   |            |
# |    fps                  | 339        |
# |    iterations           | 40         |
# |    time_elapsed         | 241        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.13470683 |
# |    clip_fraction        | 0.0942     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.293     |
# |    explained_variance   | 0.475      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.3       |
# |    n_updates            | 970        |
# |    policy_gradient_loss | -0.00917   |
# |    value_loss           | 90.3       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | -9.14     |
# | time/                   |           |
# |    fps                  | 337       |
# |    iterations           | 41        |
# |    time_elapsed         | 248       |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.1757871 |
# |    clip_fraction        | 0.131     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.317    |
# |    explained_variance   | -0.272    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 14        |
# |    n_updates            | 980       |
# |    policy_gradient_loss | -0.00399  |
# |    value_loss           | 54.6      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -6.8       |
# | time/                   |            |
# |    fps                  | 339        |
# |    iterations           | 42         |
# |    time_elapsed         | 253        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.17142788 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.382     |
# |    explained_variance   | 0.255      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23.8       |
# |    n_updates            | 990        |
# |    policy_gradient_loss | -0.0131    |
# |    value_loss           | 60         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 11.2       |
# | time/                   |            |
# |    fps                  | 343        |
# |    iterations           | 43         |
# |    time_elapsed         | 256        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.04503147 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.371     |
# |    explained_variance   | -0.113     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.8       |
# |    n_updates            | 1000       |
# |    policy_gradient_loss | -0.00882   |
# |    value_loss           | 74.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 23          |
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 44          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.041525863 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.357      |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.5        |
# |    n_updates            | 1010        |
# |    policy_gradient_loss | 0.0329      |
# |    value_loss           | 112         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 20.1       |
# | time/                   |            |
# |    fps                  | 351        |
# |    iterations           | 45         |
# |    time_elapsed         | 262        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.03213823 |
# |    clip_fraction        | 0.0779     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.311     |
# |    explained_variance   | -0.0664    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 38         |
# |    n_updates            | 1020       |
# |    policy_gradient_loss | 0.00492    |
# |    value_loss           | 91.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 18.3       |
# | time/                   |            |
# |    fps                  | 353        |
# |    iterations           | 46         |
# |    time_elapsed         | 266        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.16722888 |
# |    clip_fraction        | 0.202      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.396     |
# |    explained_variance   | 0.165      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 37.9       |
# |    n_updates            | 1030       |
# |    policy_gradient_loss | -0.0167    |
# |    value_loss           | 83.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 47           |
# |    time_elapsed         | 273          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0021725637 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.181       |
# |    explained_variance   | 0.0394       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.5         |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | 0.00789      |
# |    value_loss           | 108          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 28.4        |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 48          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.000690944 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.198      |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.4        |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.000633   |
# |    value_loss           | 124         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 29.1         |
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 49           |
# |    time_elapsed         | 288          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0015369684 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.238       |
# |    explained_variance   | 0.368        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51           |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 109          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 33.2          |
# | time/                   |               |
# |    fps                  | 346           |
# |    iterations           | 50            |
# |    time_elapsed         | 295           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 0.00049916765 |
# |    clip_fraction        | 0.0256        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.231        |
# |    explained_variance   | 0.3           |
# |    learning_rate        | 0.0003        |
# |    loss                 | 40.2          |
# |    n_updates            | 1070          |
# |    policy_gradient_loss | 0.00446       |
# |    value_loss           | 99.3          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 29.7         |
# | time/                   |              |
# |    fps                  | 345          |
# |    iterations           | 51           |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0029103796 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | 0.318        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.5         |
# |    n_updates            | 1080         |
# |    policy_gradient_loss | 0.000324     |
# |    value_loss           | 112          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 22.5       |
# | time/                   |            |
# |    fps                  | 343        |
# |    iterations           | 52         |
# |    time_elapsed         | 309        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.04823821 |
# |    clip_fraction        | 0.0524     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.275     |
# |    explained_variance   | 0.517      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 67.4       |
# |    n_updates            | 1090       |
# |    policy_gradient_loss | -0.00103   |
# |    value_loss           | 108        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 22.2        |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 53          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.017647028 |
# |    clip_fraction        | 0.08        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.3        |
# |    explained_variance   | 0.534       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.6        |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | 0.0032      |
# |    value_loss           | 99.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 28.5         |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 54           |
# |    time_elapsed         | 324          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0027395452 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.237       |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.7         |
# |    n_updates            | 1110         |
# |    policy_gradient_loss | 0.0009       |
# |    value_loss           | 113          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 36           |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 55           |
# |    time_elapsed         | 331          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0012490288 |
# ...
# | time/                   |               |
# |    fps                  | 598           |
# |    iterations           | 228           |
# |    time_elapsed         | 780           |
# |    total_timesteps      | 466944        |
# | train/                  |               |
# |    approx_kl            | 0.00034345133 |
# |    clip_fraction        | 0.00356       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0358       |
# |    explained_variance   | 0.838         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 51.9          |
# |    n_updates            | 2850          |
# |    policy_gradient_loss | -0.000714     |
# |    value_loss           | 133           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -1.62         |
# | time/                   |               |
# |    fps                  | 598           |
# |    iterations           | 229           |
# |    time_elapsed         | 783           |
# |    total_timesteps      | 468992        |
# | train/                  |               |
# |    approx_kl            | 0.00019383247 |
# |    clip_fraction        | 0.00474       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0576       |
# |    explained_variance   | 0.844         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 71.8          |
# |    n_updates            | 2860          |
# |    policy_gradient_loss | 0.00162       |
# |    value_loss           | 121           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 2.52        |
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 230         |
# |    time_elapsed         | 785         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.017722335 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.16       |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.7        |
# |    n_updates            | 2870        |
# |    policy_gradient_loss | 0.00431     |
# |    value_loss           | 124         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 5.86        |
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 231         |
# |    time_elapsed         | 788         |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.019944515 |
# |    clip_fraction        | 0.0296      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.104      |
# |    explained_variance   | 0.46        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.4        |
# |    n_updates            | 2880        |
# |    policy_gradient_loss | 0.00846     |
# |    value_loss           | 156         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 5.12        |
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 232         |
# |    time_elapsed         | 790         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.077632956 |
# |    clip_fraction        | 0.0308      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0866     |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52          |
# |    n_updates            | 2890        |
# |    policy_gradient_loss | 0.00478     |
# |    value_loss           | 119         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -7.28        |
# | time/                   |              |
# |    fps                  | 601          |
# |    iterations           | 233          |
# |    time_elapsed         | 793          |
# |    total_timesteps      | 477184       |
# | train/                  |              |
# |    approx_kl            | 0.0027650397 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.046       |
# |    explained_variance   | 0.713        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48           |
# |    n_updates            | 2900         |
# |    policy_gradient_loss | 0.00233      |
# |    value_loss           | 103          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -4.76       |
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 234         |
# |    time_elapsed         | 795         |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.007464072 |
# |    clip_fraction        | 0.00562     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0463     |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.5        |
# |    n_updates            | 2910        |
# |    policy_gradient_loss | 0.00161     |
# |    value_loss           | 108         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | -15.9     |
# | time/                   |           |
# |    fps                  | 602       |
# |    iterations           | 235       |
# |    time_elapsed         | 798       |
# |    total_timesteps      | 481280    |
# | train/                  |           |
# |    approx_kl            | 0.1357939 |
# |    clip_fraction        | 0.116     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.311    |
# |    explained_variance   | 0.801     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 88.4      |
# |    n_updates            | 2920      |
# |    policy_gradient_loss | 0.00397   |
# |    value_loss           | 135       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -11.1       |
# | time/                   |             |
# |    fps                  | 603         |
# |    iterations           | 236         |
# |    time_elapsed         | 800         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.010395993 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.158      |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.8        |
# |    n_updates            | 2930        |
# |    policy_gradient_loss | 0.00138     |
# |    value_loss           | 156         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -7.84        |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 237          |
# |    time_elapsed         | 803          |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 0.0072364933 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.122       |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77           |
# |    n_updates            | 2940         |
# |    policy_gradient_loss | -0.00185     |
# |    value_loss           | 148          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.36         |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 238          |
# |    time_elapsed         | 805          |
# |    total_timesteps      | 487424       |
# | train/                  |              |
# |    approx_kl            | 0.0012575617 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.102       |
# |    explained_variance   | 0.807        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.3         |
# |    n_updates            | 2950         |
# |    policy_gradient_loss | 0.00453      |
# |    value_loss           | 97           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 0.92        |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 239         |
# |    time_elapsed         | 808         |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.004778239 |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0734     |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.4        |
# |    n_updates            | 2960        |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 99.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -5.84       |
# | time/                   |             |
# |    fps                  | 606         |
# |    iterations           | 240         |
# |    time_elapsed         | 810         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.002361395 |
# |    clip_fraction        | 0.0274      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.128      |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.4        |
# |    n_updates            | 2970        |
# |    policy_gradient_loss | 0.0176      |
# |    value_loss           | 101         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -5.02         |
# | time/                   |               |
# |    fps                  | 606           |
# |    iterations           | 241           |
# |    time_elapsed         | 813           |
# |    total_timesteps      | 493568        |
# | train/                  |               |
# |    approx_kl            | 0.00033635306 |
# |    clip_fraction        | 0.00645       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0843       |
# |    explained_variance   | 0.814         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 50.7          |
# |    n_updates            | 2980          |
# |    policy_gradient_loss | 0.00149       |
# |    value_loss           | 113           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -1.94         |
# | time/                   |               |
# |    fps                  | 607           |
# |    iterations           | 242           |
# |    time_elapsed         | 815           |
# |    total_timesteps      | 495616        |
# | train/                  |               |
# |    approx_kl            | 0.00028433895 |
# |    clip_fraction        | 0.00703       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0539       |
# |    explained_variance   | 0.745         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 94.1          |
# |    n_updates            | 2990          |
# |    policy_gradient_loss | 0.000305      |
# |    value_loss           | 142           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -0.1          |
# | time/                   |               |
# |    fps                  | 608           |
# |    iterations           | 243           |
# |    time_elapsed         | 818           |
# |    total_timesteps      | 497664        |
# | train/                  |               |
# |    approx_kl            | 1.3154233e-05 |
# |    clip_fraction        | 0.00327       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0561       |
# |    explained_variance   | 0.808         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 55.6          |
# |    n_updates            | 3000          |
# |    policy_gradient_loss | 0.000376      |
# |    value_loss           | 109           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -8.74        |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 244          |
# |    time_elapsed         | 820          |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0004155751 |
# |    clip_fraction        | 0.00649      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0671      |
# |    explained_variance   | 0.808        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 89.9         |
# |    n_updates            | 3010         |
# |    policy_gradient_loss | 0.000207     |
# |    value_loss           | 124          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -14           |
# | time/                   |               |
# |    fps                  | 609           |
# |    iterations           | 245           |
# |    time_elapsed         | 823           |
# |    total_timesteps      | 501760        |
# | train/                  |               |
# |    approx_kl            | 0.00035715444 |
# |    clip_fraction        | 0.0083        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0746       |
# |    explained_variance   | 0.811         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 43.1          |
# |    n_updates            | 3020          |
# |    policy_gradient_loss | 0.00155       |
# |    value_loss           | 127           |
# -------------------------------------------

# %%
evaluate_policy(model, env, n_eval_episodes=10)
# Out:
# (24.0, 54.99090833947008)

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    score = 0
    done = False

    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward

    print(f"Episode: {episode} | Score: {score}")
# Out:
# Episode: 1 | Score: 60
# Episode: 2 | Score: 28
# Episode: 3 | Score: -60
# Episode: 4 | Score: -60
# Episode: 5 | Score: 60

# %% [markdown]
# ## Save Model

# %%
save_path = os.path.join('training', 'saved_models', 'PPO_500k_ShowerTemp')
model.save(save_path)
